# %%
import numpy
import json
from pathlib import Path
from importlib import reload
import sys
import os
sys.path.append(os.path.abspath('..'))
import pandas as pd
import random
from transformers import AutoModel, AutoTokenizer
from utils.SemrepOutputLoader import SemrepOutputLoader
from utils.TermEmbedder import TermEmbedder
from HGCR_util.lazy_json_kv_loader import LazyJsonlAbstractLoader
from sklearn.model_selection import train_test_split
from HGCR_util import text_util
from HGCR_util.emb_lookup.abstr_emb_lookup import MedlineNumpyEmbeddings
from tqdm import tqdm
random.seed(42)

tqdm.pandas()

# %%
import importlib
import utils

importlib.reload(utils.SemrepOutputLoader)
# Out:
# <module 'utils.SemrepOutputLoader' from '/work/acslab/users/manning/NLM_soft/agatha_0724/BioPredClassifier/utils/SemrepOutputLoader.py'>

# %%
num_samples = 60000

# %%
embeddings_fpath = Path(
    '/work/acslab/shared/medline_embeddings/PubMedNCL_abstr/abstr_id_to_emb_PubMedNCL'
)

pubmedncl_emb_obj = MedlineNumpyEmbeddings(
    emb_w_ids_fpath=embeddings_fpath,
    json_read_n_jobs=8,
)
# Out:
# Opening np chunks: 100%|█████████████████████| 102/102 [00:00<00:00, 915.34it/s]
# Opening json index chunks: 100%|██████████████| 102/102 [00:10<00:00,  9.29it/s]
# Constructing PMID lookup index: 100%|█████████| 102/102 [00:14<00:00,  7.28it/s]

# %%
sent_jsonl_dir = Path(
    '/work/acslab/shared/Agatha_shared/'
    'pmid_to_sent_id_w_text_kv_jsonl_lazy_chunks'
)

abstr_db = LazyJsonlAbstractLoader(
    list(sent_jsonl_dir.glob('*jsonl'))
)
# Out:
# Indexing jsonl files: 100%|███████████████████| 109/109 [03:57<00:00,  2.18s/it]

# %%
sr_output_dict = SemrepOutputLoader('/work/acslab/shared/rel_extraction/semrep_data/data_2021_onw/agatha_medline_sentences')
sr_output_dict._load_single_pkl_file('pubmed25n1064_sentences.pkl')
sr_output_dict._load_single_pkl_file('pubmed25n1066_sentences.pkl')
sr_output_dict._load_single_pkl_file('pubmed25n1068_sentences.pkl')
sr_output_dict._load_single_pkl_file('pubmed25n1070_sentences.pkl')
sr_output_dict._load_single_pkl_file('pubmed25n1072_sentences.pkl')
sr_output_dict._load_single_pkl_file('pubmed25n1074_sentences.pkl')
sr_output_dict._load_single_pkl_file('pubmed25n1076_sentences.pkl')

# %%
sr_output_dict._load_single_pkl_file('pubmed25n1078_sentences.pkl')
sr_output_dict._load_single_pkl_file('pubmed25n1080_sentences.pkl')
sr_output_dict._load_single_pkl_file('pubmed25n1082_sentences.pkl')
sr_output_dict._load_single_pkl_file('pubmed25n1084_sentences.pkl')

# %%
sampled_pmids = list(sr_output_dict.data_dict.keys())
filtered_sampled_pmids = [i for i in sampled_pmids if len(sr_output_dict[i][0]['relations']) >= 1]
len(sampled_pmids)
# sr_output_dict.data_dict['33383987']
# Out:
# 194877

# %%
total_pairs = 0
total_pmids = 0
for pmids, item in sr_output_dict.data_dict.items():
    total_pmids += 1
    terms = 0
    for term in item[0].get('terms'):
        terms += 1
    total_pairs += (terms * (terms-1)) / 2

# %%
total_pairs/total_pmids
# Out:
# 35.182622885204516

# %%
sampled_abstracts = {pmid: text_util.get_abstr_text(pmid, abstr_db) for pmid in tqdm(sampled_pmids, desc="Retrieving Abstracts...")}
len(sampled_abstracts)
# Out:
# Retrieving Abstracts...: 100%|████████| 194877/194877 [00:39<00:00, 4949.83it/s]
# 194877

# %%
sr_output_dict.data_dict['33383987']
# Out:
# [{'terms': {'cases',
#    'catalytic activity',
#    'contributions',
#    'cooling',
#    'degrees C',
#    'dependence',
#    'entropic',
#    'fold',
#    'highest',
#    'hydride',
#    'increase',
#    'individual',
#    'kinetic barrier',
#    'lead',
#    'outer',
#    'sphere',
#    'splitting',
#    'temperature',
#    'tetrahydrofuran',
#    'toluene',
#    'unique'},
#   'relations': {('individual', 'kinetic barrier'),
#    ('lead', 'tetrahydrofuran')},
#   'negatives': {('cases', 'catalytic activity'),
#    ('cases', 'contributions'),
#    ('cases', 'cooling'),
#    ('cases', 'degrees C'),
#    ('cases', 'dependence'),
#    ('cases', 'entropic'),
#    ('cases', 'fold'),
#    ('cases', 'highest'),
#    ('cases', 'hydride'),
#    ('cases', 'increase'),
#    ('cases', 'individual'),
#    ('cases', 'kinetic barrier'),
#    ('cases', 'lead'),
#    ('cases', 'outer'),
#    ('cases', 'sphere'),
#    ('cases', 'splitting'),
#    ('cases', 'temperature'),
#    ('cases', 'tetrahydrofuran'),
#    ('cases', 'toluene'),
#    ('cases', 'unique'),
#    ('catalytic activity', 'contributions'),
#    ('catalytic activity', 'cooling'),
#    ('catalytic activity', 'degrees C'),
#    ('catalytic activity', 'dependence'),
#    ('catalytic activity', 'entropic'),
#    ('catalytic activity', 'fold'),
#    ('catalytic activity', 'highest'),
#    ('catalytic activity', 'hydride'),
#    ('catalytic activity', 'increase'),
#    ('catalytic activity', 'individual'),
#    ('catalytic activity', 'kinetic barrier'),
#    ('catalytic activity', 'lead'),
#    ('catalytic activity', 'outer'),
#    ('catalytic activity', 'sphere'),
#    ('catalytic activity', 'splitting'),
#    ('catalytic activity', 'temperature'),
#    ('catalytic activity', 'tetrahydrofuran'),
#    ('catalytic activity', 'toluene'),
#    ('catalytic activity', 'unique'),
#    ('contributions', 'cooling'),
#    ('contributions', 'degrees C'),
#    ('contributions', 'dependence'),
#    ('contributions', 'entropic'),
#    ('contributions', 'fold'),
#    ('contributions', 'highest'),
#    ('contributions', 'hydride'),
#    ('contributions', 'increase'),
#    ('contributions', 'individual'),
#    ('contributions', 'kinetic barrier'),
#    ('contributions', 'lead'),
#    ('contributions', 'outer'),
#    ('contributions', 'sphere'),
#    ('contributions', 'splitting'),
#    ('contributions', 'temperature'),
#    ('contributions', 'tetrahydrofuran'),
#    ('contributions', 'toluene'),
#    ('contributions', 'unique'),
#    ('cooling', 'cooling'),
#    ('cooling', 'degrees C'),
#    ('cooling', 'dependence'),
#    ('cooling', 'entropic'),
#    ('cooling', 'fold'),
#    ('cooling', 'highest'),
#    ('cooling', 'hydride'),
#    ('cooling', 'increase'),
#    ('cooling', 'individual'),
#    ('cooling', 'kinetic barrier'),
#    ('cooling', 'lead'),
#    ('cooling', 'outer'),
#    ('cooling', 'sphere'),
#    ('cooling', 'splitting'),
#    ('cooling', 'temperature'),
#    ('cooling', 'tetrahydrofuran'),
#    ('cooling', 'toluene'),
#    ('cooling', 'unique'),
#    ('degrees C', 'dependence'),
#    ('degrees C', 'entropic'),
#    ('degrees C', 'fold'),
#    ('degrees C', 'highest'),
#    ('degrees C', 'hydride'),
#    ('degrees C', 'increase'),
#    ('degrees C', 'individual'),
#    ('degrees C', 'kinetic barrier'),
#    ('degrees C', 'lead'),
#    ('degrees C', 'outer'),
#    ('degrees C', 'sphere'),
#    ('degrees C', 'splitting'),
#    ('degrees C', 'temperature'),
#    ('degrees C', 'tetrahydrofuran'),
#    ('degrees C', 'toluene'),
#    ('degrees C', 'unique'),
#    ('dependence', 'entropic'),
#    ('dependence', 'fold'),
#    ('dependence', 'highest'),
#    ('dependence', 'hydride'),
#    ('dependence', 'increase'),
#    ('dependence', 'individual'),
#    ('dependence', 'kinetic barrier'),
#    ('dependence', 'lead'),
#    ('dependence', 'outer'),
#    ('dependence', 'sphere'),
#    ('dependence', 'splitting'),
#    ('dependence', 'temperature'),
#    ('dependence', 'tetrahydrofuran'),
#    ('dependence', 'toluene'),
#    ('dependence', 'unique'),
#    ('entropic', 'fold'),
#    ('entropic', 'highest'),
#    ('entropic', 'hydride'),
#    ('entropic', 'increase'),
#    ('entropic', 'individual'),
#    ('entropic', 'kinetic barrier'),
#    ('entropic', 'lead'),
#    ('entropic', 'outer'),
#    ('entropic', 'sphere'),
#    ('entropic', 'splitting'),
#    ('entropic', 'temperature'),
#    ('entropic', 'tetrahydrofuran'),
#    ('entropic', 'toluene'),
#    ('entropic', 'unique'),
#    ('fold', 'fold'),
#    ('fold', 'highest'),
#    ('fold', 'hydride'),
#    ('fold', 'increase'),
#    ('fold', 'individual'),
#    ('fold', 'kinetic barrier'),
#    ('fold', 'lead'),
#    ('fold', 'outer'),
#    ('fold', 'sphere'),
#    ('fold', 'splitting'),
#    ('fold', 'temperature'),
#    ('fold', 'tetrahydrofuran'),
#    ('fold', 'toluene'),
#    ('fold', 'unique'),
#    ('highest', 'hydride'),
#    ('highest', 'increase'),
#    ('highest', 'individual'),
#    ('highest', 'kinetic barrier'),
#    ('highest', 'lead'),
#    ('highest', 'outer'),
#    ('highest', 'sphere'),
#    ('highest', 'splitting'),
#    ('highest', 'temperature'),
#    ('highest', 'tetrahydrofuran'),
#    ('highest', 'toluene'),
#    ('highest', 'unique'),
#    ('hydride', 'increase'),
#    ('hydride', 'individual'),
#    ('hydride', 'kinetic barrier'),
#    ('hydride', 'lead'),
#    ('hydride', 'outer'),
#    ('hydride', 'sphere'),
#    ('hydride', 'splitting'),
#    ('hydride', 'temperature'),
#    ('hydride', 'tetrahydrofuran'),
#    ('hydride', 'toluene'),
#    ('hydride', 'unique'),
#    ('increase', 'increase'),
#    ('increase', 'individual'),
#    ('increase', 'kinetic barrier'),
#    ('increase', 'lead'),
#    ('increase', 'outer'),
#    ('increase', 'sphere'),
#    ('increase', 'splitting'),
#    ('increase', 'temperature'),
#    ('increase', 'tetrahydrofuran'),
#    ('increase', 'toluene'),
#    ('increase', 'unique'),
#    ('individual', 'lead'),
#    ('individual', 'outer'),
#    ('individual', 'sphere'),
#    ('individual', 'splitting'),
#    ('individual', 'temperature'),
#    ('individual', 'tetrahydrofuran'),
#    ('individual', 'toluene'),
#    ('individual', 'unique'),
#    ('kinetic barrier', 'lead'),
#    ('kinetic barrier', 'outer'),
#    ('kinetic barrier', 'sphere'),
#    ('kinetic barrier', 'splitting'),
#    ('kinetic barrier', 'temperature'),
#    ('kinetic barrier', 'tetrahydrofuran'),
#    ('kinetic barrier', 'toluene'),
#    ('kinetic barrier', 'unique'),
#    ('lead', 'outer'),
#    ('lead', 'sphere'),
#    ('lead', 'splitting'),
#    ('lead', 'temperature'),
#    ('lead', 'toluene'),
#    ('lead', 'unique'),
#    ('outer', 'sphere'),
#    ('outer', 'splitting'),
#    ('outer', 'temperature'),
#    ('outer', 'tetrahydrofuran'),
#    ('outer', 'toluene'),
#    ('outer', 'unique'),
#    ('sphere', 'splitting'),
#    ('sphere', 'temperature'),
#    ('sphere', 'tetrahydrofuran'),
#    ('sphere', 'toluene'),
#    ('sphere', 'unique'),
#    ('splitting', 'temperature'),
#    ('splitting', 'tetrahydrofuran'),
#    ('splitting', 'toluene'),
#    ('splitting', 'unique'),
#    ('temperature', 'temperature'),
#    ('temperature', 'tetrahydrofuran'),
#    ('temperature', 'toluene'),
#    ('temperature', 'unique'),
#    ('tetrahydrofuran', 'toluene'),
#    ('tetrahydrofuran', 'unique'),
#    ('toluene', 'unique')}}]

# %%
sampled_embeds = {}
for pmid in sampled_pmids:
    try:
        sampled_embeds[pmid] = pubmedncl_emb_obj[pmid]
    except:
        continue
len(sampled_embeds)
# Out:
# 194874

# %%
sr_terms = {pmid: sr_output_dict[pmid][0].get('terms') for pmid in tqdm(sampled_pmids, desc="Retrieving Semrep terms...")}
sr_pairs = {pmid: sr_output_dict[pmid][0].get('relations') for pmid in tqdm(sampled_pmids, desc="Retrieving Semrep pairs...")}
# Out:
# ving Semrep terms...:   0%|                    | 0/194877 [00:00<?, ?it/s]
#
# ving Semrep terms...:  46%|█▊  | 90038/194877 [00:00<00:00, 900335.78it/s]
#
# Retrieving Semrep terms...: 100%|███| 194877/194877 [00:00<00:00, 820796.92it/s]
#
#
# ving Semrep pairs...:   0%|                    | 0/194877 [00:00<?, ?it/s]
#
# ving Semrep pairs...:  48%|█▉  | 94344/194877 [00:00<00:00, 943375.67it/s]
#
# Retrieving Semrep pairs...: 100%|███| 194877/194877 [00:00<00:00, 901498.52it/s]

# %%
all_terms = []
for terms in sr_terms.values():
    for term in terms:
        all_terms.append(term)
for pairs in sr_pairs.values():
    for t1, t2 in pairs:
        all_terms.append(t1)
        all_terms.append(t2)
all_terms = list(set(all_terms))
len(all_terms), all_terms[0]
# Out:
# (202682, 'waiting list')

# %%
term_embedder = TermEmbedder()

# %%
term_embeddings = term_embedder._batch_term_embeds(all_terms)

# %%
import pickle
with open('term_embeddings/term_embeddings_60k_pmid.pkl', 'wb') as file:
    pickle.dump(term_embeddings, file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 import pickle
# ----> 2 with open('term_embeddings/term_embeddings_60k_pmid.pkl', 'wb') as file:
#       3     pickle.dump(term_embeddings, file)
#
# File /work/acslab/users/manning/anaconda/envs/agatha_0724/lib/python3.9/site-packages/IPython/core/interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'term_embeddings/term_embeddings_60k_pmid.pkl'

# %%
pmids_w_all_info = [pmid for pmid in sampled_pmids if pmid in sampled_abstracts and pmid in sampled_embeds]
len(pmids_w_all_info)
# Out:
# 194874

# %%
df = pd.DataFrame({
    'pmid': [pmid for pmid in pmids_w_all_info],
    'abstract': [sampled_abstracts[pmid] for pmid in pmids_w_all_info],
    'abstract_embeddings': [sampled_embeds[pmid] for pmid in pmids_w_all_info],
    'terms': [list(sr_output_dict[pmid][0]['terms']) for pmid in pmids_w_all_info],
    'relations': [list(sr_output_dict[pmid][0]['relations']) for pmid in pmids_w_all_info],
    'negatives': [list(sr_output_dict[pmid][0]['negatives']) for pmid in pmids_w_all_info],

})

df.head()
# Out:
#        pmid                                           abstract  \
# 0  33383987  Temperature and Solvent Effects on H2 Splittin...
# 1  33383988  Mechanism for Rapid Conversion of Amines to Am...
# 2  33383989  Bisecting GlcNAc Protein N-Glycosylation Is Ch...
# 3  33383992  Association of Exposure to Cattle with Self-Re...
# 4  33383995  The Effect of Preoperative Video Based Pain Tr...
#
#                                  abstract_embeddings  \
# 0  [-0.28345045, -0.54292804, 0.16380529, 0.15494...
# 1  [-0.2850943, -0.80024165, -0.11266672, 0.14250...
# 2  [-0.040046073, -1.0489765, -0.37665504, -0.493...
# 3  [-0.310526, -0.5039563, 0.6601208, -0.08117764...
# 4  [0.091471456, -0.07006314, -0.11821665, -0.306...
#
#                                                terms  \
# 0  [fold, lead, cooling, tetrahydrofuran, splitti...
# 1  [Particle, Conversion, Amines, Ammonium Salts,...
# 2  [Protein N-Glycosylation, Adipogenesis, Human,...
# 3  [relationship, human, study, bovine tuberculos...
# 4  [Analgesic, Control Group, Effect, Video, Pain...
#
#                                            relations  \
# 0  [(individual, kinetic barrier), (lead, tetrahy...
# 1                         [(Amines, Ammonium Salts)]
# 2                            [(Adipogenesis, Human)]
# 3                                  [(health, human)]
# 4  [(Postoperative Pain, Total Knee Arthroplasty)...
#
#                                            negatives
# 0  [(fold, tetrahydrofuran), (cases, toluene), (e...
# 1  [(Particle, Rapid), (Conversion, Rapid), (Conv...
# 2  [(Adipogenesis, Protein N-Glycosylation), (Cha...
# 3  [(health, relationship), (bovine tuberculosis,...
# 4  [(Analgesic, Postoperative Pain), (Effect, Vid...

# %%
def map_terms(row):
    terms = row['terms']
    embeds = []
    for term in terms:
        embeds.append(term_embeddings[term])
    return embeds

def map_pairs(row):
    pairs = row['relations']
    pair_embeds = []
    for t1, t2 in pairs:
        t1_embed = term_embeddings[t1]
        t2_embed = term_embeddings[t2]
        pair_embeds.append((t1_embed, t2_embed))
    return pair_embeds

def map_negatives(row):
    negatives = row['negatives']
    negative_embeds = []
    for t1, t2 in negatives:
        t1_embed = term_embeddings[t1]
        t2_embed = term_embeddings[t2]
        negative_embeds.append((t1_embed, t2_embed))
    return negative_embeds

# %%
df['term_embeddings'] = df.progress_apply(map_terms, axis=1)
df['pair_embeddings'] = df.progress_apply(map_pairs, axis=1)
df['negatives_embeddings'] = df.progress_apply(map_negatives, axis=1)
df.head()
# Out:
# 100%|███████████████████████████████| 194874/194874 [00:01<00:00, 104433.05it/s]
# 100%|███████████████████████████████| 194874/194874 [00:01<00:00, 108145.89it/s]
# 100%|████████████████████████████████| 194874/194874 [00:03<00:00, 50372.67it/s]
#        pmid                                           abstract  \
# 0  33383987  Temperature and Solvent Effects on H2 Splittin...
# 1  33383988  Mechanism for Rapid Conversion of Amines to Am...
# 2  33383989  Bisecting GlcNAc Protein N-Glycosylation Is Ch...
# 3  33383992  Association of Exposure to Cattle with Self-Re...
# 4  33383995  The Effect of Preoperative Video Based Pain Tr...
#
#                                  abstract_embeddings  \
# 0  [-0.28345045, -0.54292804, 0.16380529, 0.15494...
# 1  [-0.2850943, -0.80024165, -0.11266672, 0.14250...
# 2  [-0.040046073, -1.0489765, -0.37665504, -0.493...
# 3  [-0.310526, -0.5039563, 0.6601208, -0.08117764...
# 4  [0.091471456, -0.07006314, -0.11821665, -0.306...
#
#                                                terms  \
# 0  [fold, lead, cooling, tetrahydrofuran, splitti...
# 1  [Particle, Conversion, Amines, Ammonium Salts,...
# 2  [Protein N-Glycosylation, Adipogenesis, Human,...
# 3  [relationship, human, study, bovine tuberculos...
# 4  [Analgesic, Control Group, Effect, Video, Pain...
#
#                                            relations  \
# 0  [(individual, kinetic barrier), (lead, tetrahy...
# 1                         [(Amines, Ammonium Salts)]
# 2                            [(Adipogenesis, Human)]
# 3                                  [(health, human)]
# 4  [(Postoperative Pain, Total Knee Arthroplasty)...
#
#                                            negatives  \
# 0  [(fold, tetrahydrofuran), (cases, toluene), (e...
# 1  [(Particle, Rapid), (Conversion, Rapid), (Conv...
# 2  [(Adipogenesis, Protein N-Glycosylation), (Cha...
# 3  [(health, relationship), (bovine tuberculosis,...
# 4  [(Analgesic, Postoperative Pain), (Effect, Vid...
#
#                                      term_embeddings  \
# 0  [[-0.28223613, -0.0036575377, 0.08042424, -0.1...
# 1  [[-0.5166602, 0.11687658, -0.09206407, -0.0107...
# 2  [[-0.7968025, -0.20326202, -0.566039, -0.13663...
# 3  [[-0.25283906, 0.11320739, -0.30629858, -0.038...
# 4  [[-0.51707596, 0.17515965, -0.48447058, -0.293...
#
#                                      pair_embeddings  \
# 0  [([-0.7495256, 0.36571825, -0.84759635, -0.030...
# 1  [([-0.34281886, 0.30733573, -0.13176091, 0.137...
# 2  [([-0.21563068, 0.16044843, -0.39353308, -0.15...
# 3  [([0.006518982, 0.25178033, -0.0104505485, -0....
# 4  [([-0.38955075, 0.314926, -0.6473092, -0.47112...
#
#                                 negatives_embeddings
# 0  [([-0.28223613, -0.0036575377, 0.08042424, -0....
# 1  [([-0.5166602, 0.11687658, -0.09206407, -0.010...
# 2  [([-0.21563068, 0.16044843, -0.39353308, -0.15...
# 3  [([0.006518982, 0.25178033, -0.0104505485, -0....
# 4  [([-0.51707596, 0.17515965, -0.48447058, -0.29...

# %%
from itertools import combinations

def generate_negative_samples(row):
    terms = set(row['terms'])
    pairs = {tuple(sorted(pair)) for pair in row['relations']}

    all_possible_negatives = {tuple(sorted(pair)) for pair in combinations(terms, 2)}

    negative_pairs = list(all_possible_negatives - pairs)

    negative_pair_embeddings = [(term_embeddings[pair[0]], term_embeddings[pair[1]]) for pair in negative_pairs]

    return pd.Series([negative_pairs, negative_pair_embeddings])

df[['negative_pairs', 'negative_pair_embeddings']] = df.progress_apply(generate_negative_samples, axis=1)
# Out:
# 100%|██████████████████████████████████| 194880/194880 [03:20<00:00, 972.42it/s]

# %%
pos = 0
neg = 0
for idx, row in df.iterrows():
    num_pos = len(row['relations'])
    num_neg = len(row['negative_pairs'])
    pos += num_pos
    neg += num_neg

neg/pos
# Out:
# 84.99117967344438

# %%
df.head()
# Out:
#        pmid                                           abstract  \
# 0  33383987  Temperature and Solvent Effects on H2 Splittin...
# 1  33383988  Mechanism for Rapid Conversion of Amines to Am...
# 2  33383989  Bisecting GlcNAc Protein N-Glycosylation Is Ch...
# 3  33383992  Association of Exposure to Cattle with Self-Re...
# 4  33383995  The Effect of Preoperative Video Based Pain Tr...
#
#                                  abstract_embeddings  \
# 0  [-0.28345045, -0.54292804, 0.16380529, 0.15494...
# 1  [-0.2850943, -0.80024165, -0.11266672, 0.14250...
# 2  [-0.040046073, -1.0489765, -0.37665504, -0.493...
# 3  [-0.310526, -0.5039563, 0.6601208, -0.08117764...
# 4  [0.091471456, -0.07006314, -0.11821665, -0.306...
#
#                                                terms  \
# 0  [unique, dependence, increase, kinetic barrier...
# 1  [SA, amines, heterogeneous, more, Born, scales...
# 2  [structural, Protein N-Glycosylation, total, m...
# 3  [One Health, bovine tuberculosis, study, human...
# 4  [preoperative, video, pain levels, operation, ...
#
#                                            relations  \
# 0  [(kinetic barrier, individual), (tetrahydrofur...
# 1  [(Amines, Ammonium Salts), (methylamine, sulfu...
# 2  [(adipose-derived stem cells, cell types), (gl...
# 3                                  [(health, human)]
# 4  [(Total Knee Arthroplasty, Patients), (total k...
#
#                                      term_embeddings  \
# 0  [[-0.17409305, 0.14344533, -0.08849688, 0.0577...
# 1  [[-0.2324654, 0.15819652, 0.13121484, -0.16349...
# 2  [[-0.36078623, 0.14125407, -0.13912392, -0.101...
# 3  [[-0.25943512, -0.07382132, -0.3403496, -0.090...
# 4  [[-0.34140453, -0.05907702, -0.2574163, -0.370...
#
#                                      pair_embeddings  \
# 0  [([-0.3733754, 0.3167213, -0.109789714, 0.1208...
# 1  [([-0.34281886, 0.30733573, -0.13176091, 0.137...
# 2  [([-0.54336065, -0.51505405, -0.42755878, 0.51...
# 3  [([0.006518982, 0.25178033, -0.0104505485, -0....
# 4  [([-0.8438509, 0.14522868, -0.4953759, -0.1401...
#
#                                       negative_pairs  \
# 0  [(catalytic activity, degrees C), (splitting, ...
# 1  [(Rapid, methylamine), (effect, sulfuric acid)...
# 2  [(PGC-LC, glycan), (protein N, three), (adipoc...
# 3  [(health, study), (One Health, health), (bovin...
# 4  [(non-randomized control group intervention st...
#
#                             negative_pair_embeddings
# 0  [([-0.5648823, 0.017226646, -0.004290537, -0.3...
# 1  [([-0.5999069, 0.08327565, -0.2641165, -0.0731...
# 2  [([-0.79083776, -0.288387, -0.16368967, -0.216...
# 3  [([0.006518982, 0.25178033, -0.0104505485, -0....
# 4  [([-0.49223354, -0.864952, -0.7692929, -0.1749...

# %%
chunk_size = 1000
output_dir = '60k_pmid_dataset_chunks_sentencewise_negatives'
os.makedirs(output_dir, exist_ok=True)

for i, start in enumerate(range(0, len(df), chunk_size)):
    df_chunk = df.iloc[start:start+chunk_size]
    chunk_path = os.path.join(output_dir, f"chunk_{i}.pkl")
    df_chunk.to_pickle(chunk_path)
    print(f"Saved {chunk_path}")
# Out:
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_0.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_1.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_2.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_3.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_4.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_5.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_6.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_7.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_8.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_9.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_10.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_11.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_12.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_13.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_14.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_15.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_46.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_47.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_48.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_49.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_50.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_51.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_52.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_53.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_54.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_55.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_56.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_57.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_58.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_59.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_60.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_61.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_62.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_63.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_64.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_65.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_66.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_67.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_68.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_69.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_70.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_71.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_72.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_73.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_74.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_75.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_76.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_77.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_78.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_79.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_80.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_81.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_82.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_83.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_84.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_85.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_86.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_87.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_88.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_89.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_90.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_91.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_92.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_93.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_94.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_95.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_96.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_97.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_98.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_99.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_100.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_101.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_102.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_103.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_104.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_105.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_106.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_107.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_108.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_109.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_110.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_111.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_112.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_113.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_114.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_115.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_116.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_117.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_118.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_119.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_120.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_121.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_122.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_123.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_124.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_125.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_126.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_127.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_128.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_129.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_130.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_131.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_132.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_133.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_134.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_135.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_136.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_137.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_138.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_139.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_140.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_141.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_142.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_143.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_144.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_145.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_146.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_147.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_148.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_149.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_150.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_151.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_152.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_153.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_154.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_155.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_156.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_157.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_158.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_159.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_160.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_161.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_162.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_163.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_164.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_165.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_166.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_167.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_168.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_169.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_170.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_171.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_172.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_173.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_174.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_175.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_176.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_177.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_178.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_179.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_180.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_181.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_182.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_183.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_184.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_185.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_186.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_187.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_188.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_189.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_190.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_191.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_192.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_193.pkl
# Saved 60k_pmid_dataset_chunks_sentencewise_negatives/chunk_194.pkl

# %%
len(df.iloc[0]['pair_embeddings'])
# Out:
# 2

# %%
df.iloc[1000]['pair_embeddings'][0][0].shape
# Out:
# (768,)

# %%
df.head(1)
# Out:
#        pmid                                           abstract  \
# 0  33439050  Radiohistologic Comparison Study of Temporal B...
#
#                                  abstract_embeddings  \
# 0  [0.1367508, -0.20444079, -0.7152996, -0.035280...
#
#                                                terms  \
# 0  [specimen, data, inner, Cochlear Implant, coch...
#
#                                            relations  \
# 0  [(spiral lamina, osseous), (bone structures, o...
#
#                                      term_embeddings  \
# 0  [[-0.55541235, -0.023848163, -0.04390437, -0.0...
#
#                                      pair_embeddings  \
# 0  [([-0.3612353, -0.29702, 0.16018414, -0.321839...
#
#                                   negative_relations  \
# 0  [(Cone-Beam CT, implantation), (data, images),...
#
#                         negative_relation_embeddings
# 0  [([-0.7141436, -0.29975635, 0.07302878, -0.255...
