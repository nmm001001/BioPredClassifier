# %% [markdown]
# # CUI pairs differences between real and rephrased abstracts: SemRep processing

# %%
import pandas as pd
from pathlib import Path

from collections import defaultdict

# %% [markdown]
# ## Initializing SemRep

# %%
from agatha.construct.semrep_handler import SemRepHandler

# %%
nlm_soft_folder = '/lustre/acslab/users/2288/NLM_soft'
sr_temp_folder = '/lustre/acslab/users/2288/scratch_dir/sr_temp/021225'
sr_replace_utf8_path = '/lustre/acslab/users/2288/NLM_soft/replace_utf8.jar'

# %%
t = SemRepHandler(
    nlm_soft_path=nlm_soft_folder,
    temp_folder=sr_temp_folder,
    #restart_mm_services=True,
    replace_utf8_path=sr_replace_utf8_path,
)
# Out:
# Existing services killed.
# Starting wsdserverctl:
# started.
# loading properties file /lustre/acslab/users/2288/NLM_soft/public_mm/WSD_Server/config/disambServer.cfg
#
# SKR and WSD services started.

# %%
t.sr_binary_path = Path('/lustre/acslab/users/2288/NLM_soft/public_semrep/bin/semrep.v1.9_2021AB')

# %%
t.ProcessList_parallel(['Moderna COVID-19 vaccine treats Coronavirus disease'])
# Out:
# Run SemRep in interactive mode...
# Processing input with replace_utf8.jar utility...
# {'s:user_input_0:1': {'sent_text': 'Moderna COVID-19 vaccine treats Coronavirus disease ',
#   'terms': [{'CID': 'C5424056',
#     'pref_name': 'Moderna COVID-19 Vaccine',
#     'extracted_text': 'Moderna COVID-19 vaccine',
#     'label': 'UMLS',
#     'sem_types': ['imft', 'nnon', 'phsu'],
#     'negated': False},
#    {'CID': 'C5401375',
#     'pref_name': 'Coronaviridae Measurement',
#     'extracted_text': 'Coronavirus',
#     'label': 'UMLS',
#     'sem_types': ['lbpr'],
#     'negated': False},
#    {'CID': 'C0012634',
#     'pref_name': 'Disease',
#     'extracted_text': 'disease',
#     'label': 'UMLS',
#     'sem_types': ['dsyn'],
#     'negated': False}],
#   'relations': [{'subj_id': 'C5424056',
#     'subj_name': 'Moderna COVID-19 Vaccine',
#     'subj_text': 'Moderna COVID-19 vaccine',
#     'subj_sem_type': 'phsu',
#     'subj_negated': False,
#     'verb': 'TREATS',
#     'verb_negated': False,
#     'obj_id': 'C0012634',
#     'obj_name': 'Disease',
#     'obj_text': 'disease',
#     'obj_sem_type': 'dsyn',
#     'obj_negated': False}]}}

# %% [markdown]
# ## Opening results

# %%
pmids_df = pd.read_pickle('data/021225/100_pmids.pkl')

# %%
pmids_df
# Out:
#         pmid                                          pmid_text  \
# 0    1883399  Substrate analogues and divalent cations as in...
# 1   32887154  Comparison of capillary electrophoresis and zw...
# 2    1654513  Angiotensin II receptor subtypes and biologica...
# 3   11814052  Mechanisms of self-incompatibility in flowerin...
# 4   16350614  Accuracy and speed of orthographic processing ...
# ..       ...                                                ...
# 95   3682109  Leads from the MMWR. Premature mortality due t...
# 96  21937697  High endothelial venules as traffic control po...
# 97  26985970  Screening of Toxic Chemicals in a Single Drop ...
# 98  17340633  Predicting DNA-binding amino acid residues fro...
# 99  18469453  Ritonavir and disulfiram may be synergistic in...
#
#                                        rewritten_text  \
# 0   To explore whether glutamate decarboxylase fro...
# 1   This study compares zwitterionic-hydrophilic i...
# 2   Research on angiotensin II (AII) receptor subt...
# 3   Self-incompatibility is a common mechanism in ...
# 4   A study compared 39 individuals with developme...
# ..                                                ...
# 95  The MMWR reports on early deaths caused by bre...
# 96  High endothelial venules (HEVs) serve as cruci...
# 97  We introduce a novel approach for detecting to...
# 98  To predict DNA-binding amino acid residues, we...
# 99  Ritonavir and disulfiram might work together t...
#
#                                   original_text_preds  \
# 0   [(glutamate decarboxylase, source for study of...
# 1   [(capillary electrophoresis, comparison), (zwi...
# 2   [(Angiotensin II receptor subtypes, biological...
# 3   [(self-incompatibility, mechanism), (self-inco...
# 4   [(persons with developmental dyslexia, orthogr...
# ..                                                ...
# 95                                                 []
# 96  [(High endothelial venules, traffic control po...
# 97  [(Surface-enhanced laser desorption/ionization...
# 98  [(DNA-binding amino acid residues, predicted f...
# 99  [(Ritonavir, lowering active interleukin-18 le...
#
#                                  rewritten_text_preds
# 0   [(Escherichia coli glutamate decarboxylase, mo...
# 1   [(study, compares capZIC-HILIC and CE), (study...
# 2   [(Rat and bovine adrenal zona glomerulosa cell...
# 3   [(Self-incompatibility, mechanism in flowering...
# 4   [(study, compared individuals with development...
# ..                                                ...
# 95  [(MMWR, reports on early deaths), (early death...
# 96  [(High endothelial venules (HEVs), regulate th...
# 97  [(novel approach, detecting toxic chemicals), ...
# 98  [(positively charged atoms, clusters), (cluste...
# 99                                                 []
#
# [100 rows x 5 columns]

# %%
pmids_df['original_text_preds'].apply(lambda x: [len(p) for p in x])
# Out:
# 0                     [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 1     [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, ...
# 2     [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, ...
# 3     [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, ...
# 4                  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#                             ...
# 95                                                   []
# 96        [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 97           [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 98                 [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 99                    [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# Name: original_text_preds, Length: 100, dtype: object

# %% [markdown]
# ## Running SemRep to map entities

# %%
all_ents_list = []
for rec in pmids_df['original_text_preds']:
    for e in rec:
        all_ents_list += e
    
for rec in pmids_df['rewritten_text_preds']:
    for e in rec:
        all_ents_list += e

# %%
len(all_ents_list)
# Out:
# 5556

# %%
len(set([w.lower() for w in all_ents_list]))
# Out:
# 3724

# %%
all_ents_list = list(set(all_ents_list))
len(all_ents_list)
# Out:
# 3812

# %%
# %%time
r_out_dict = t.ProcessList_parallel(all_ents_list, chunkSize=50)
# Out:
# Run SemRep in interactive mode...
# Processing input with replace_utf8.jar utility...
# CPU times: user 163 ms, sys: 267 ms, total: 430 ms
# Wall time: 2min 36s

# %% [markdown]
# ## Applying SemRep mapping`

# %%
str_terms_to_cui_dict = defaultdict(set)
for k,v in r_out_dict.items():
    sent_text = v['sent_text'][:-1]
    for t in v['terms']:
        str_terms_to_cui_dict[sent_text].add(t['pref_name'])

# %%
str_terms_to_cui_dict['enhanced diagnostic accuracy for nodal metastasis in esophageal squamous cell carcinoma']
# Out:
# {'Diagnostic Accuracy',
#  'Enhance (action)',
#  'NODAL gene',
#  'Secondary Neoplasm',
#  'Squamous cell carcinoma of esophagus'}

# %%
pmids_df
# Out:
#         pmid                                          pmid_text  \
# 0    1883399  Substrate analogues and divalent cations as in...
# 1   32887154  Comparison of capillary electrophoresis and zw...
# 2    1654513  Angiotensin II receptor subtypes and biologica...
# 3   11814052  Mechanisms of self-incompatibility in flowerin...
# 4   16350614  Accuracy and speed of orthographic processing ...
# ..       ...                                                ...
# 95   3682109  Leads from the MMWR. Premature mortality due t...
# 96  21937697  High endothelial venules as traffic control po...
# 97  26985970  Screening of Toxic Chemicals in a Single Drop ...
# 98  17340633  Predicting DNA-binding amino acid residues fro...
# 99  18469453  Ritonavir and disulfiram may be synergistic in...
#
#                                        rewritten_text  \
# 0   To explore whether glutamate decarboxylase fro...
# 1   This study compares zwitterionic-hydrophilic i...
# 2   Research on angiotensin II (AII) receptor subt...
# 3   Self-incompatibility is a common mechanism in ...
# 4   A study compared 39 individuals with developme...
# ..                                                ...
# 95  The MMWR reports on early deaths caused by bre...
# 96  High endothelial venules (HEVs) serve as cruci...
# 97  We introduce a novel approach for detecting to...
# 98  To predict DNA-binding amino acid residues, we...
# 99  Ritonavir and disulfiram might work together t...
#
#                                   original_text_preds  \
# 0   [(glutamate decarboxylase, source for study of...
# 1   [(capillary electrophoresis, comparison), (zwi...
# 2   [(Angiotensin II receptor subtypes, biological...
# 3   [(self-incompatibility, mechanism), (self-inco...
# 4   [(persons with developmental dyslexia, orthogr...
# ..                                                ...
# 95                                                 []
# 96  [(High endothelial venules, traffic control po...
# 97  [(Surface-enhanced laser desorption/ionization...
# 98  [(DNA-binding amino acid residues, predicted f...
# 99  [(Ritonavir, lowering active interleukin-18 le...
#
#                                  rewritten_text_preds
# 0   [(Escherichia coli glutamate decarboxylase, mo...
# 1   [(study, compares capZIC-HILIC and CE), (study...
# 2   [(Rat and bovine adrenal zona glomerulosa cell...
# 3   [(Self-incompatibility, mechanism in flowering...
# 4   [(study, compared individuals with development...
# ..                                                ...
# 95  [(MMWR, reports on early deaths), (early death...
# 96  [(High endothelial venules (HEVs), regulate th...
# 97  [(novel approach, detecting toxic chemicals), ...
# 98  [(positively charged atoms, clusters), (cluste...
# 99                                                 []
#
# [100 rows x 5 columns]
# Bad id: user_input_2709 Error code: 1
# Skipped record: user_input_2710|enable regulation

# %%
def get_umls_pairs(r):
    umls_pairs_set = set()
    
    for t1, t2 in r:
        cur_t1_terms = str_terms_to_cui_dict.get(t1)
        cur_t2_terms = str_terms_to_cui_dict.get(t2)
        
        if cur_t1_terms and cur_t2_terms:
            for t1t in cur_t1_terms:
                for t2t in cur_t2_terms:
                    umls_pairs_set.add(
                        tuple(sorted([t1t, t2t]))
                    )
                    
    return umls_pairs_set

# %%
pmids_df['original_text_preds_umls'] = pmids_df['original_text_preds'].apply(get_umls_pairs)
pmids_df['rewritten_text_preds_umls'] = pmids_df['rewritten_text_preds'].apply(get_umls_pairs)

# %% [markdown]
# ## Finding terms differences

# %%
pmids_df['intersect_umls'] = pmids_df.apply(
    lambda x: x['original_text_preds_umls'].intersection(
        x['rewritten_text_preds_umls']
    ),
    axis=1
)

pmids_df['diff_umls'] = pmids_df.apply(
    lambda x: x['original_text_preds_umls'].symmetric_difference(
        x['rewritten_text_preds_umls']
    ),
    axis=1
)

# %%
pmids_df.applymap(len)
# Out:
# /tmp/ipykernel_17030/1480685510.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pmids_df.applymap(len)
#     pmid  pmid_text  rewritten_text  original_text_preds  \
# 0      7       1196             999                   11
# 1      8       1716            1384                   31
# 2      7       2194            1841                   24
# 3      8       1221             939                   20
# 4      8       1085             993                   12
# ..   ...        ...             ...                  ...
# 95     7         83              86                    0
# 96     8       1390            1361                   15
# 97     8       1477            1182                   14
# 98     8       1359            1063                   12
# 99     8       1436            1379                   11
#
#     rewritten_text_preds  original_text_preds_umls  rewritten_text_preds_umls  \
# 0                     21                        62                         62
# 1                     18                        53                         34
# 2                     22                       129                        191
# 3                     14                        33                         29
# 4                      8                        50                         34
# ..                   ...                       ...                        ...
# 95                     4                         0                          3
# 96                    11                        17                         20
# 97                    19                        50                         40
# 98                    24                        96                         27
# 99                     0                        40                          0
#
#     intersect_umls  diff_umls
# 0               19         86
# 1                0         87
# 2               72        176
# 3                3         56
# 4                3         78
# ..             ...        ...
# 95               0          3
# 96               5         27
# 97              15         60
# 98              11        101
# 99               0         40
#
# [100 rows x 9 columns]

# %%
pmids_df
# Out:
#         pmid                                          pmid_text  \
# 0    1883399  Substrate analogues and divalent cations as in...
# 1   32887154  Comparison of capillary electrophoresis and zw...
# 2    1654513  Angiotensin II receptor subtypes and biologica...
# 3   11814052  Mechanisms of self-incompatibility in flowerin...
# 4   16350614  Accuracy and speed of orthographic processing ...
# ..       ...                                                ...
# 95   3682109  Leads from the MMWR. Premature mortality due t...
# 96  21937697  High endothelial venules as traffic control po...
# 97  26985970  Screening of Toxic Chemicals in a Single Drop ...
# 98  17340633  Predicting DNA-binding amino acid residues fro...
# 99  18469453  Ritonavir and disulfiram may be synergistic in...
#
#                                        rewritten_text  \
# 0   To explore whether glutamate decarboxylase fro...
# 1   This study compares zwitterionic-hydrophilic i...
# 2   Research on angiotensin II (AII) receptor subt...
# 3   Self-incompatibility is a common mechanism in ...
# 4   A study compared 39 individuals with developme...
# ..                                                ...
# 95  The MMWR reports on early deaths caused by bre...
# 96  High endothelial venules (HEVs) serve as cruci...
# 97  We introduce a novel approach for detecting to...
# 98  To predict DNA-binding amino acid residues, we...
# 99  Ritonavir and disulfiram might work together t...
#
#                                   original_text_preds  \
# 0   [(glutamate decarboxylase, source for study of...
# 1   [(capillary electrophoresis, comparison), (zwi...
# 2   [(Angiotensin II receptor subtypes, biological...
# 3   [(self-incompatibility, mechanism), (self-inco...
# 4   [(persons with developmental dyslexia, orthogr...
# ..                                                ...
# 95                                                 []
# 96  [(High endothelial venules, traffic control po...
# 97  [(Surface-enhanced laser desorption/ionization...
# 98  [(DNA-binding amino acid residues, predicted f...
# 99  [(Ritonavir, lowering active interleukin-18 le...
#
#                                  rewritten_text_preds  \
# 0   [(Escherichia coli glutamate decarboxylase, mo...
# 1   [(study, compares capZIC-HILIC and CE), (study...
# 2   [(Rat and bovine adrenal zona glomerulosa cell...
# 3   [(Self-incompatibility, mechanism in flowering...
# 4   [(study, compared individuals with development...
# ..                                                ...
# 95  [(MMWR, reports on early deaths), (early death...
# 96  [(High endothelial venules (HEVs), regulate th...
# 97  [(novel approach, detecting toxic chemicals), ...
# 98  [(positively charged atoms, clusters), (cluste...
# 99                                                 []
#
#                              original_text_preds_umls  \
# 0   {(inhibitors, zinc cation), (Analog, Inhibitor...
# 1   {(Liquid Chromatography, Permutation), (Abunda...
# 2   {(Cell Count, Receptor, Angiotensin II), (NLRP...
# 3   {(Endoribonucleases, pollen tube growth), (Inb...
# 4   {(Age Cohort, Groups), (Disabled, Laboratory P...
# ..                                                ...
# 95                                                 {}
# 96  {(Hepatitis E virus, Steady-State), (Lymphocyt...
# 97  {(Carbon, Ionization), (Carbon, Choose (action...
# 98  {(Mutation, Strategy), (DNA Binding, Residue),...
# 99  {(Active, ritonavir), (Interleukin-18, Pancrea...
#
#                             rewritten_text_preds_umls  \
# 0   {(Compound, IMPACT gene), (Potential, isophtha...
# 1   {(Impacted, Nebulizers), (Analyte, L-lysine 6-...
# 2   {(Cell Count, Receptor, Angiotensin II), (Bark...
# 3   {(Inbreeding, self incompatibility), (Family, ...
# 4   {(Groups, Smaller), (Participant, Study), (Pho...
# ..                                                ...
# 95  {(Malignant neoplasm of breast, United States)...
# 96  {(High Endothelial Venule, Lesch-Nyhan Syndrom...
# 97  {(Background, Carbon), (Carbon, Salt Tolerance...
# 98  {(Methods, Post-Translational Protein Processi...
# 99                                                 {}
#
#                                        intersect_umls  \
# 0   {(Bacterial, Model), (Cations, Divalent, inhib...
# 1                                                  {}
# 2   {(Cell Count, Receptor, Angiotensin II), (Inte...
# 3   {(Inbreeding, self incompatibility), (Brassica...
# 4   {(Control Groups, age differences), (Accurate ...
# ..                                                ...
# 95                                                 {}
# 96  {(Lymphocyte, Mammals), (High Endothelial Venu...
# 97  {(Carbon, Compound), (Macrophage Activation Sy...
# 98  {(Methods, Post-Translational Protein Processi...
# 99                                                 {}
#
#                                             diff_umls
# 0   {(Compound, IMPACT gene), (Enzymes, Glutamate ...
# 1   {(Liquid Chromatography, Permutation), (Impact...
# 2   {(Bark - plant part, Cattle), (Known, SLC33A1 ...
# 3   {(Endoribonucleases, pollen tube growth), (Fam...
# 4   {(Participant, Study), (Delta (difference), Ol...
# ..                                                ...
# 95  {(Malignant neoplasm of breast, United States)...
# 96  {(High Endothelial Venule, Lesch-Nyhan Syndrom...
# 97  {(Background, Carbon), (Carbon, Salt Tolerance...
# 98  {(Mutation, Strategy), (DNA Binding, Detected ...
# 99  {(Active, ritonavir), (Homo sapiens, disulfira...
#
# [100 rows x 9 columns]

# %%
pmids_df
# Out:
#         pmid                                          pmid_text  \
# 0    1883399  Substrate analogues and divalent cations as in...
# 1   32887154  Comparison of capillary electrophoresis and zw...
# 2    1654513  Angiotensin II receptor subtypes and biologica...
# 3   11814052  Mechanisms of self-incompatibility in flowerin...
# 4   16350614  Accuracy and speed of orthographic processing ...
# ..       ...                                                ...
# 95   3682109  Leads from the MMWR. Premature mortality due t...
# 96  21937697  High endothelial venules as traffic control po...
# 97  26985970  Screening of Toxic Chemicals in a Single Drop ...
# 98  17340633  Predicting DNA-binding amino acid residues fro...
# 99  18469453  Ritonavir and disulfiram may be synergistic in...
#
#                                        rewritten_text  \
# 0   To explore whether glutamate decarboxylase fro...
# 1   This study compares zwitterionic-hydrophilic i...
# 2   Research on angiotensin II (AII) receptor subt...
# 3   Self-incompatibility is a common mechanism in ...
# 4   A study compared 39 individuals with developme...
# ..                                                ...
# 95  The MMWR reports on early deaths caused by bre...
# 96  High endothelial venules (HEVs) serve as cruci...
# 97  We introduce a novel approach for detecting to...
# 98  To predict DNA-binding amino acid residues, we...
# 99  Ritonavir and disulfiram might work together t...
#
#                                   original_text_preds  \
# 0   [(glutamate decarboxylase, source for study of...
# 1   [(capillary electrophoresis, comparison), (zwi...
# 2   [(Angiotensin II receptor subtypes, biological...
# 3   [(self-incompatibility, mechanism), (self-inco...
# 4   [(persons with developmental dyslexia, orthogr...
# ..                                                ...
# 95                                                 []
# 96  [(High endothelial venules, traffic control po...
# 97  [(Surface-enhanced laser desorption/ionization...
# 98  [(DNA-binding amino acid residues, predicted f...
# 99  [(Ritonavir, lowering active interleukin-18 le...
#
#                                  rewritten_text_preds  \
# 0   [(Escherichia coli glutamate decarboxylase, mo...
# 1   [(study, compares capZIC-HILIC and CE), (study...
# 2   [(Rat and bovine adrenal zona glomerulosa cell...
# 3   [(Self-incompatibility, mechanism in flowering...
# 4   [(study, compared individuals with development...
# ..                                                ...
# 95  [(MMWR, reports on early deaths), (early death...
# 96  [(High endothelial venules (HEVs), regulate th...
# 97  [(novel approach, detecting toxic chemicals), ...
# 98  [(positively charged atoms, clusters), (cluste...
# 99                                                 []
#
#                              original_text_preds_umls  \
# 0   {(inhibitors, zinc cation), (Analog, Inhibitor...
# 1   {(Liquid Chromatography, Permutation), (Abunda...
# 2   {(Cell Count, Receptor, Angiotensin II), (NLRP...
# 3   {(Endoribonucleases, pollen tube growth), (Inb...
# 4   {(Age Cohort, Groups), (Disabled, Laboratory P...
# ..                                                ...
# 95                                                 {}
# 96  {(Hepatitis E virus, Steady-State), (Lymphocyt...
# 97  {(Carbon, Ionization), (Carbon, Choose (action...
# 98  {(Mutation, Strategy), (DNA Binding, Residue),...
# 99  {(Active, ritonavir), (Interleukin-18, Pancrea...
#
#                             rewritten_text_preds_umls  \
# 0   {(Compound, IMPACT gene), (Potential, isophtha...
# 1   {(Impacted, Nebulizers), (Analyte, L-lysine 6-...
# 2   {(Cell Count, Receptor, Angiotensin II), (Bark...
# 3   {(Inbreeding, self incompatibility), (Family, ...
# 4   {(Groups, Smaller), (Participant, Study), (Pho...
# ..                                                ...
# 95  {(Malignant neoplasm of breast, United States)...
# 96  {(High Endothelial Venule, Lesch-Nyhan Syndrom...
# 97  {(Background, Carbon), (Carbon, Salt Tolerance...
# 98  {(Methods, Post-Translational Protein Processi...
# 99                                                 {}
#
#                                        intersect_umls  \
# 0   {(Bacterial, Model), (Cations, Divalent, inhib...
# 1                                                  {}
# 2   {(Cell Count, Receptor, Angiotensin II), (Inte...
# 3   {(Inbreeding, self incompatibility), (Brassica...
# 4   {(Control Groups, age differences), (Accurate ...
# ..                                                ...
# 95                                                 {}
# 96  {(Lymphocyte, Mammals), (High Endothelial Venu...
# 97  {(Carbon, Compound), (Macrophage Activation Sy...
# 98  {(Methods, Post-Translational Protein Processi...
# 99                                                 {}
#
#                                             diff_umls
# 0   {(Compound, IMPACT gene), (Enzymes, Glutamate ...
# 1   {(Liquid Chromatography, Permutation), (Impact...
# 2   {(Bark - plant part, Cattle), (Known, SLC33A1 ...
# 3   {(Endoribonucleases, pollen tube growth), (Fam...
# 4   {(Participant, Study), (Delta (difference), Ol...
# ..                                                ...
# 95  {(Malignant neoplasm of breast, United States)...
# 96  {(High Endothelial Venule, Lesch-Nyhan Syndrom...
# 97  {(Background, Carbon), (Carbon, Salt Tolerance...
# 98  {(Mutation, Strategy), (DNA Binding, Detected ...
# 99  {(Active, ritonavir), (Homo sapiens, disulfira...
#
# [100 rows x 9 columns]

# %%
pmids_df.to_pickle('data/021225/100_pmids_w_umls_terms.pkl')
